# %%
import time
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import pandas as pd
import os

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait

# %%
# Error Page
# First Abu Dhabi Islamic Finance P.J.S.C.

# %%
driverPath=r"C:\Users\Merit\Desktop\MAIN-PROJECT\chromedriver.exe"
driver = webdriver.Chrome(driverPath)
driver.get("https://www.zawya.com/mena/en/companies/list/cso/?keyword=Islamic%20Finance%20&country=&sector=&ownership=&resultsPerPage=10&page=2")
Name=[]
Country=[]
Estabilished=[]
Sector=[]
Address=[]
Region=[]
Email=[]
Link=[]    

for x in range(3,7):
    for i in range (1,11):
        click = driver.find_element_by_xpath("//a[contains(text(),'LEARN MORE')]//following::a["+str(i)+"]")
        driver.execute_script("arguments[0].click();",click)    
#         driver.find_element_by_xpath("//a[contains(text(),'LEARN MORE')]//following::a["+str(i)+"]").click()
        name= driver.find_elements_by_xpath("//h1[@class='page-title']") 
        for j in name:
            Name.append(j.text)
        country=driver.find_elements_by_xpath("//h3[contains(text(),'fast facts')]//following::strong[1]")
        for a in country:
            Country.append(a.text)
            
        estabilished=driver.find_elements_by_xpath("//h3[contains(text(),'fast facts')]//following::strong[2]")
        for c in estabilished:
            Estabilished.append(c.text)
            
        sector=driver.find_elements_by_xpath("//h3[contains(text(),'fast facts')]//following::strong[3]")
        for b in sector:
            Sector.append(b.text)
            
        address=driver.find_elements_by_xpath("//h5//following::address")
        for l in address:
            Address.append(l.text)
        region=driver.find_elements_by_xpath("//h5[contains(text(),'Region')]//following::strong[1]")
        for m in region:
            Region.append(m.text)
        email=driver.find_elements_by_xpath("//a[@class='email']")
        for m in email:
            Email.append(m.text)
        link=driver.find_elements_by_xpath(" //h5[contains(text(),'CONTACT')]//following::li[2]")
#         //h5[contains(text(),'CONTACT')]//following::li[2]
        for n in link:
            Link.append(n.text)
        driver.back()
        time.sleep(2)
    button = driver.find_element_by_xpath("//a[@class='page-link next fa fa-angle-right']")
    driver.execute_script("arguments[0].click();", button)
driver.close()

# %%
data = pd.DataFrame(list(zip(Name,Country,Estabilished,Sector,Address,Region,Email,Link)),columns=["Name","Country","Estabilished","Sector","Address","Region","Email","Link"])
pd.options.display.max_rows
pd.set_option('display.max_rows', None)
data
# Out:
#                                                  Name       Country  \
# 0                          Audi Investment Bank S.A.L       Lebanon
# 1                    Capital Bank of Jordan (EXFB.AM)       Bahrain
# 2            Capivest Investment Bank B.S.C. (merged)         Qatar
# 3      Takaful International Company B.S.C. (TAKA.BH)           UAE
# 4                                         QInvest LLC  Saudi Arabia
# 5                     Invest bank P.S.C. (INVESTB.AD)           UAE
# 6                        AAFAQ Islamic Finance P.S.C.           UAE
# 7                                INVESTBANK (INVB.AM)           UAE
# 8              Khaleeji Commercial Bank BSC (KHCB.BH)         Yemen
# 9     International Islamic Trade Finance Corporation       Lebanon
# 10  Abu Dhabi Commercial Islamic Finance Pvt. J.S....  Saudi Arabia
# 11         Aseel Finance P.J.S.C. (under liquidation)           UAE
# 12                     Islamic Finance House P.J.S.C.        Kuwait
# 13  Islamic Bank of Yemen for Finance and Investme...       Lebanon
# 14  Al-Sanabel International for Islamic Investmen...           UAE
# 15              Arab Finance House SAL (Islamic Bank)          Iraq
# 16                                  Alkhabeer Capital           UAE
# 17  Alisraa for Islamic Finance & Investment P.L.C...          Iraq
# 18           First Abu Dhabi Islamic Finance P.J.S.C.           UAE
# 19         Raqaba for Islamic Financial Consultations         Sudan
# 20                     Al Baraka Bank Egypt (SAUD.CA)           UAE
# 21  Al-Bilad Islamic Bank for Investment & Finance...        Kuwait
# 22                First Finance Company plc (FFCO.AM)        Jordan
# 23                                AMANIE Advisors LTD         Egypt
# 24     Al-Bilad Islamic Bank for Investment & Finance       Lebanon
# 25                         Mashreq Al Islami (merged)         Qatar
# 26  Cihan Bank for Islamic Investment and Finance ...           UAE
# 27          Dar Al Sharia Islamic Finance Company LLC           UAE
# 28                            Export Development Bank       Lebanon
# 29                            NBD Securities (merged)  Saudi Arabia
#
#    Estabilished                     Sector  \
# 0          1974         Financial Services
# 1          1981         Financial Services
# 2          2007         Financial Services
# 3          2006         Financial Services
# 4          2008         Financial Services
# 5          2009         Financial Services
# 6          2006         Financial Services
# 7          2008         Financial Services
# 8          1995         Financial Services
# 9          2006         Financial Services
# 10         2004         Financial Services
# 11         2007         Financial Services
# 12         2010         Financial Services
# 13         2010         Financial Services
# 14         2008                   Services
# 15         2006         Financial Services
# 16         2006         Financial Services
# 17         2008         Financial Services
# 18         2007                   Services
# 19         1981         Financial Services
# 20         2000         Financial Services
# 21         1986         Financial Services
# 22         2007         Financial Services
# 23         1995         Financial Services
# 24         2009         Financial Services
# 25         2006         Financial Services
# 26         1995  Governmental Institutions
# 27         1997         Financial Services
# 28         2012                   Services
# 29         2014         Financial Services
#
#                                               Address               Region  \
# 0   Building: Bank Audi sal Building\nStreet: Amer...               Beirut
# 1   Building: Capital Bank of Jordan Building\nStr...  Capital Governorate
# 2                      Country: Bahrain\nCity: Manama              Capital
# 3   Building: Building 680\nStreet: Road 2811\nFlo...              Capital
# 4   Building: Tornado Tower\nStreet: Majlis Al Taw...                 Doha
# 5   Building: Invest bank P.S.C. Building\nStreet:...              Sharjah
# 6   Building: Al Saqr Business Tower\nStreet: Shei...                Dubai
# 7   Building: Building 43\nStreet: Abdul Hamid Sha...  Capital Governorate
# 8   Building: East Tower\nArea: Bahrain Financial ...              Capital
# 9   Building: Islamic Development Bank Building\nS...               Makkah
# 10                      Country: UAE\nCity: Abu Dhabi            Abu Dhabi
# 11  Building: Aseel Finance P.J.S.C. Building\nStr...            Abu Dhabi
# 12  Building: Al Blooshi Building\nStreet: Electra...            Abu Dhabi
# 13  Building: Mareb Insurance Company Building\nSt...                Sanaa
# 14  Building: Taha Al Husany Building 38\nStreet: ...  Capital Governorate
# 15  Building: Arab Finance House Holding Company B...               Beirut
# 16  Building: Alkhabeer Capital Building\nStreet: ...               Makkah
# 17  Building: Building 197\nStreet: Al Madina Al M...  Capital Governorate
# 18  Building: Golden Beach Tower\nStreet: Corniche...            Abu Dhabi
# 19  Building: Al Salam Tower\nStreet: Fahad Al Sal...           Al Assimah
# 20  Building: Building 60\nStreet: Mohieddine Abu ...                 Giza
# 21  Building: Broadway Center\nStreet: Hamra Stree...               Beirut
# 22  Building: Building 172\nStreet: King Abdullah ...  Capital Governorate
# 23  Building: Al Fattan Currency House, Tower 2\nF...                Dubai
# 24  Building: Building 1\nStreet: Street 37\nArea:...              Baghdad
# 25  Building: Cihan Bank for Islamic Investment an...                Erbil
# 26  Building: Al Masaood Building\nStreet: Al Makt...                Dubai
# 27  Building: Export Development Bank Building\nSt...              Unknown
# 28                          Country: UAE\nCity: Dubai                Dubai
# 29  Building: Kuwait Stock Exchange Building\nStre...           Al Assimah
#
#                             Email  \
# 0        contactus@bankaudiib.com
# 1             info@capitalbank.jo
# 2           takaful@gigtakaful.bh
# 3                info@qinvest.com
# 4           sharjah@investbank.ae
# 5                   info@aafaq.ae
# 6              info@investbank.jo
# 7             info@khcbonline.com
# 8                   itfc@isdb.org
# 9            info@aseelfinance.ae
# 10         customerservice@ifh.ae
# 11       islamicbank@iby-bank.com
# 12           info@sanabelintl.com
# 13                info@afh.com.lb
# 14             info@alkhabeer.com
# 15              info@israa.com.jo
# 16  centeral@albaraka-bank.com.eg
# 17            info@abibank.com.lb
# 18                    info@ffc.jo
# 19        info@amanieadvisors.com
# 20             info@biladbank.com
# 21             info@cihanbank.com
# 22            info@daralsharia.ae
# 23                  edb@edbank.sd
# 24         info.kw@efg-hermes.com
# 25   kuwait-online@efg-hermes.com
# 26             osoul@osoulnet.com
# 27                info@bobfin.com
# 28                info@dof.gov.ae
# 29           info@gulffinance.com
#
#                                                  Link
# 0                                 www.bankaudi.com.lb
# 1                                  www.capitalbank.jo
# 2                           https://www.gigtakaful.bh
# 3                                     www.qinvest.com
# 4                                   www.investbank.ae
# 5                                        www.aafaq.ae
# 6                                   www.investbank.jo
# 7                                  www.khcbonline.com
# 8                                    www.itfc-idb.org
# 9                                 www.aseelfinance.ae
# 10                                         www.ifh.ae
# 11  KPMG Yemen Mejanni and Company\nFinancial Serv...
# 12                                www.sanabelintl.com
# 13                                     www.afh.com.lb
# 14                                  www.alkhabeer.com
# 15                                 FINANCIAL SERVICES
# 16           SSK Enterprises\nFinancial Services, UAE
# 17  Crowe Al Muhanna & Co.\nFinancial Services, Ku...
# 18                           www.albaraka-bank.com.eg
# 19  Banque Nationale de Paris Intercontinentale\nF...
# 20                                         www.ffc.jo
# 21                             www.amanieadvisors.com
# 22                                 www.bilad-bank.com
# 23                               www.cihanbank.com.iq
# 24  Classic Partnership Advertising (L.L.C)\nServi...
# 25                                          edbank.sd
# 26                Email: kuwait-online@efg-hermes.com
# 27                            www.osoulinvestment.com
# 28                                www.bob-finance.com
# 29                                     www.dof.gov.ae

# %%
Address
# Out:
# ['Building: Bank Audi sal Building\nStreet: Amer Baud Street\nFloor: 1st Floor\nArea: Bab Idriss Area\nP.O. Box: 16 5110\nCountry: Lebanon\nCity: Beirut\nCity Suffix: 2021 8102',
#  'Building: Capital Bank of Jordan Building\nStreet: Issam Ajlouni Street\nArea: Shmeisani Area\nP.O. Box: 941283\nCountry: Jordan\nCity: Amman\nCity Suffix: 11194',
#  'Country: Bahrain\nCity: Manama',
#  'Building: Building 680\nStreet: Road 2811\nFloor: 4th Floor\nArea: Seef District 428\nP.O. Box: 3230\nCountry: Bahrain\nCity: Manama',
#  'Building: Tornado Tower\nStreet: Majlis Al Tawoon Street 213\nFloor: 39th Floor\nArea: West Bay Area, Zone 60\nP.O. Box: 26222\nCountry: Qatar\nCity: Al Rayyan',
#  'Building: Cihan Bank for Islamic Investment and Finance P.S.C. Building\nStreet: Kerkuk Road\nArea: Mantikawa Area\nP.O. Box: 0116-17\nCountry: Iraq\nCity: Erbil',
#  'Building: Al Masaood Building\nStreet: Al Maktoum Street\nFloor: 2nd Floor, Office 201\nArea: Deira Area\nP.O. Box: 12988\nCountry: UAE\nCity: Dubai',
#  'Building: Export Development Bank Building\nStreet: Gamhoria Avenue\nP.O. Box: 3575\nCountry: Sudan\nCity: Khartoum',
#  'Country: UAE\nCity: Dubai',
#  'Building: Kuwait Stock Exchange Building\nStreet: Mubarak Al Kabir Street\nFloor: 4th Floor\nP.O. Box: 22695\nCountry: Kuwait\nCity: Kuwait City\nCity Suffix: Safat 13087',
#  'Building: Aaraya Tower\nStreet: Al Shuhada Street\nFloor: 27th Floor\nArea: Al Sharq Area\nP.O. Box: 3880\nCountry: Kuwait\nCity: Safat\nCity Suffix: 13039',
#  'Country: Jordan\nCity: Amman',
#  'Country: Egypt\nCity: Cairo',
#  'Building: Daaboul Building\nStreet: Saint Rita Street\nFloor: Ground Floor\nArea: Horsh Tabet Area\nP.O. Box: 117354\nCountry: Lebanon\nCity: Beirut',
#  'Country: Qatar\nCity: Al Rayyan',
#  "Building: Dubai Ruler's Court Building\nStreet: Al Seef Road\nFloor: 4th and 5th Floor\nArea: Bur Dubai\nP.O. Box: 516\nCountry: UAE\nCity: Dubai",
#  'Building: Tiffany Tower Building\nFloor: 29th Floor\nArea: Jumeirah Lakes Towers Area\nP.O. Box: 35356\nCountry: UAE\nCity: Dubai',
#  'Building: Saroulla Building\nStreet: Hamra Main Street\nFloor: 8th Floor\nCountry: Lebanon\nCity: Beirut',
#  'Building: Aljabr Financing Company Building\nStreet: Amr bin Mohammad bin Fahad Road 7942\nArea: Al-Badi Area\nP.O. Box: 32415 - 4174\nCountry: Saudi Arabia\nCity: Dammam']

# %%
driverPath=r"C:\Users\Merit\Desktop\MAIN-PROJECT\chromedriver.exe"
driver = webdriver.Chrome(driverPath)
driver.get("https://www.zawya.com/mena/en/companies/list/cso/?keyword=Islamic%20Finance%20&country=&sector=&ownership=&resultsPerPage=10&page=2")
# print(driver.title)
Name=[]
Facts=[]
Address=[]
Region=[]
Email=[]
Link=[]
# for x in range(1,3): 
try:
    for i in range (1,11):
        driver.find_element_by_xpath("//a[contains(text(),'LEARN MORE')]//following::a["+str(i)+"]").click()
        name= driver.find_elements_by_xpath("//h1[@class='page-title']") 
        for j in name:
            Name.append(j.text)
        fact=driver.find_elements_by_xpath("//span[@class='label-value']")
        for k in fact:
            Facts.append(k.text)
    #         test=driver.find_elements_by_xpath("//h3[contains(text(),'fast facts')]")
    #     test1=test.get_attribute('title')
    #         print(test)
        address=driver.find_elements_by_xpath("//h5//following::address")
        for l in address:
            Address.append(l.text)
        region=driver.find_elements_by_xpath("//h5[contains(text(),'Region')]//following::strong[1]")
        for m in region:
            Region.append(m.text)
        email=driver.find_elements_by_xpath("//a[@class='email']")
        for m in email:
            Email.append(m.text)
        link=driver.find_elements_by_xpath("//a[@rel='nofollow']")
        for n in link:
            Link.append(n.text)
        driver.back()
    time.sleep(2)
except:
    print("Come on Meera")
# Out:
# Come on Meera
